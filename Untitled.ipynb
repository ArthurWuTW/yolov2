# %%
from keras.models import Sequential, Model
from keras.layers import Reshape, Activation, Conv2D, Input, MaxPooling2D, BatchNormalization, Flatten, Dense, Lambda
from keras.layers.advanced_activations import LeakyReLU
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
from keras.optimizers import SGD, Adam, RMSprop
from keras.layers.merge import concatenate
import matplotlib.pyplot as plt
import keras.backend as K
import tensorflow as tf
import imgaug as ia
from imgaug import augmenters as iaa
from tqdm import tqdm_notebook
import numpy as np
import json
import pickle
import os, cv2
from preprocessing import parse_annotation, BatchGenerator
from utils import WeightReader, decode_netout, draw_boxes
import time as time
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
#os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
#os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
LABELS = ['RBC']

IMAGE_H, IMAGE_W = 416, 416
GRID_H,  GRID_W  = 13 , 13
BOX              = 5
CLASS            = len(LABELS)
CLASS_WEIGHTS    = np.ones(CLASS, dtype='float32')
OBJ_THRESHOLD    = 0.3
NMS_THRESHOLD    = 0.3
ANCHORS          = [0.57273, 0.677385, 1.87446, 2.06253, 3.33843, 5.47434, 7.88282, 3.52778, 9.77052, 9.16828]

NO_OBJECT_SCALE  = 1.0
OBJECT_SCALE     = 5.0
COORD_SCALE      = 1.0
CLASS_SCALE      = 1.0

BATCH_SIZE       = 16
WARM_UP_BATCHES  = 100
TRUE_BOX_BUFFER  = 50

# %%
wt_path = 'yolo.weights'

# %%
generator_config = {
    'IMAGE_H'         : IMAGE_H, 
    'IMAGE_W'         : IMAGE_W,
    'GRID_H'          : GRID_H,  
    'GRID_W'          : GRID_W,
    'BOX'             : BOX,
    'LABELS'          : LABELS,
    'CLASS'           : len(LABELS),
    'ANCHORS'         : ANCHORS,
    'BATCH_SIZE'      : BATCH_SIZE,
    'TRUE_BOX_BUFFER' : 50,
}

# %%
image_path = 'dataset/JPEGImages/'
annot_path = 'dataset/Annotations/'

all_imgs, seen_labels = parse_annotation(annot_path, image_path)

# %%
all_imgs
# Out:
# [{'filename': 'dataset/JPEGImages/BloodImage_00000.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 484,
#     'xmin': 281,
#     'ymax': 299,
#     'ymin': 126}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00001.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 265,
#     'xmin': 100,
#     'ymax': 149,
#     'ymin': 10}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00002.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 507,
#     'xmin': 337,
#     'ymax': 479,
#     'ymin': 384}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00003.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 319,
#     'xmin': 151,
#     'ymax': 424,
#     'ymin': 273}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00004.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 317,
#     'xmin': 148,
#     'ymax': 318,
#     'ymin': 171}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00005.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 435,
#     'xmin': 247,
#     'ymax': 149,
#     'ymin': 11}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00006.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 279,
#     'xmin': 134,
#     'ymax': 289,
#     'ymin': 139}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00007.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 396,
#     'xmin': 253,
#     'ymax': 382,
#     'ymin': 235}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00008.jpg',
#   'height': 480,
#   'object': [{'name': 'BASOPHIL',
#     'xmax': 272,
#     'xmin': 61,
#     'ymax': 297,
#     'ymin': 97}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00009.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 253,
#     'xmin': 26,
#     'ymax': 316,
#     'ymin': 58}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00011.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 270,
#     'xmin': 132,
#     'ymax': 346,
#     'ymin': 164}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00012.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 199,
#     'xmin': 48,
#     'ymax': 276,
#     'ymin': 131}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00013.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 196,
#     'xmin': 55,
#     'ymax': 248,
#     'ymin': 106}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00014.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 371,
#     'xmin': 252,
#     'ymax': 249,
#     'ymin': 135}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00015.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 360,
#     'xmin': 157,
#     'ymax': 463,
#     'ymin': 260}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00016.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 303,
#     'xmin': 172,
#     'ymax': 328,
#     'ymin': 224}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00017.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 314,
#     'xmin': 143,
#     'ymax': 233,
#     'ymin': 121}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00018.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 468,
#     'xmin': 341,
#     'ymax': 458,
#     'ymin': 345}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00019.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 280,
#     'xmin': 131,
#     'ymax': 359,
#     'ymin': 222}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00020.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 462,
#     'xmin': 367,
#     'ymax': 111,
#     'ymin': 35}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00021.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 462,
#     'xmin': 348,
#     'ymax': 166,
#     'ymin': 52}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00022.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 262,
#     'xmin': 148,
#     'ymax': 255,
#     'ymin': 130}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00023.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 255,
#     'xmin': 127,
#     'ymax': 422,
#     'ymin': 297}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00024.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 463,
#     'xmin': 330,
#     'ymax': 479,
#     'ymin': 387}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00026.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 561,
#     'xmin': 408,
#     'ymax': 479,
#     'ymin': 380}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00028.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 421,
#     'xmin': 273,
#     'ymax': 479,
#     'ymin': 331}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00029.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 196,
#     'xmin': 87,
#     'ymax': 294,
#     'ymin': 176}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00030.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 123,
#     'xmin': 16,
#     'ymax': 274,
#     'ymin': 157}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00032.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 272,
#     'xmin': 167,
#     'ymax': 401,
#     'ymin': 289}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00033.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 275,
#     'xmin': 164,
#     'ymax': 360,
#     'ymin': 245}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00035.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 313,
#     'xmin': 210,
#     'ymax': 186,
#     'ymin': 76}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00036.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 257,
#     'xmin': 121,
#     'ymax': 226,
#     'ymin': 66}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00037.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 525,
#     'xmin': 434,
#     'ymax': 168,
#     'ymin': 71}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00038.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 532,
#     'xmin': 440,
#     'ymax': 169,
#     'ymin': 69}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00039.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 228,
#     'xmin': 125,
#     'ymax': 260,
#     'ymin': 142}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00040.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 436,
#     'xmin': 1,
#     'ymax': 339,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00041.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 640,
#     'xmin': 284,
#     'ymax': 479,
#     'ymin': 124}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00042.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 261,
#     'xmin': 150,
#     'ymax': 272,
#     'ymin': 170}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00045.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 619,
#     'xmin': 495,
#     'ymax': 442,
#     'ymin': 352}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00046.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 426,
#     'xmin': 332,
#     'ymax': 479,
#     'ymin': 395}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00047.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 379,
#     'xmin': 284,
#     'ymax': 328,
#     'ymin': 230}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00048.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 332,
#     'xmin': 211,
#     'ymax': 316,
#     'ymin': 194}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00049.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 272,
#     'xmin': 169,
#     'ymax': 226,
#     'ymin': 127}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00050.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 303,
#     'xmin': 180,
#     'ymax': 473,
#     'ymin': 379}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00052.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 242,
#     'xmin': 124,
#     'ymax': 232,
#     'ymin': 145}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00053.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 225,
#     'xmin': 118,
#     'ymax': 457,
#     'ymin': 352}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00054.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 253,
#     'xmin': 164,
#     'ymax': 406,
#     'ymin': 323}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00055.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 260,
#     'xmin': 171,
#     'ymax': 329,
#     'ymin': 245}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00056.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 379,
#     'xmin': 291,
#     'ymax': 242,
#     'ymin': 134}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00057.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 298,
#     'xmin': 188,
#     'ymax': 389,
#     'ymin': 286}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00058.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 330,
#     'xmin': 225,
#     'ymax': 472,
#     'ymin': 366}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00059.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 320,
#     'xmin': 217,
#     'ymax': 304,
#     'ymin': 193}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00062.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 233,
#     'xmin': 104,
#     'ymax': 213,
#     'ymin': 92}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00063.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 476,
#     'xmin': 378,
#     'ymax': 167,
#     'ymin': 66}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00064.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 153,
#     'xmin': 50,
#     'ymax': 342,
#     'ymin': 246}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00066.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 569,
#     'xmin': 453,
#     'ymax': 272,
#     'ymin': 161}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00067.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 243,
#     'xmin': 149,
#     'ymax': 128,
#     'ymin': 11}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00068.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 84,
#     'xmin': 1,
#     'ymax': 246,
#     'ymin': 143}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00069.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 476,
#     'xmin': 358,
#     'ymax': 217,
#     'ymin': 106}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00071.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 280,
#     'xmin': 192,
#     'ymax': 118,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00072.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 301,
#     'xmin': 208,
#     'ymax': 186,
#     'ymin': 88}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00073.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 333,
#     'xmin': 227,
#     'ymax': 424,
#     'ymin': 333}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00074.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 116,
#     'xmin': 29,
#     'ymax': 455,
#     'ymin': 356}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00075.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 317,
#     'xmin': 180,
#     'ymax': 466,
#     'ymin': 378}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00076.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 208,
#     'xmin': 112,
#     'ymax': 242,
#     'ymin': 137}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00077.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 282,
#     'xmin': 160,
#     'ymax': 375,
#     'ymin': 284}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00078.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 231,
#     'xmin': 129,
#     'ymax': 163,
#     'ymin': 45}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00079.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 103,
#     'xmin': 1,
#     'ymax': 276,
#     'ymin': 172}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00081.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 430,
#     'xmin': 314,
#     'ymax': 120,
#     'ymin': 37}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00082.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 369,
#     'xmin': 279,
#     'ymax': 131,
#     'ymin': 27}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00083.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 476,
#     'xmin': 104,
#     'ymax': 456,
#     'ymin': 94}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00086.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 186,
#     'xmin': 82,
#     'ymax': 345,
#     'ymin': 249}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00087.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 288,
#     'xmin': 201,
#     'ymax': 255,
#     'ymin': 162}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00088.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 367,
#     'xmin': 270,
#     'ymax': 247,
#     'ymin': 130}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00089.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 444,
#     'xmin': 316,
#     'ymax': 241,
#     'ymin': 112}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00090.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 352,
#     'xmin': 255,
#     'ymax': 207,
#     'ymin': 115}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00091.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 325,
#     'xmin': 234,
#     'ymax': 471,
#     'ymin': 367}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00092.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 400,
#     'xmin': 298,
#     'ymax': 424,
#     'ymin': 324}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00093.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 134,
#     'xmin': 30,
#     'ymax': 479,
#     'ymin': 392}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00094.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 530,
#     'xmin': 308,
#     'ymax': 356,
#     'ymin': 161}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00095.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 406,
#     'xmin': 200,
#     'ymax': 479,
#     'ymin': 300}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00096.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 575,
#     'xmin': 182,
#     'ymax': 411,
#     'ymin': 192}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00097.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 516,
#     'xmin': 294,
#     'ymax': 379,
#     'ymin': 198}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00098.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 339,
#     'xmin': 187,
#     'ymax': 331,
#     'ymin': 193}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00099.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 370,
#     'xmin': 232,
#     'ymax': 243,
#     'ymin': 143}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00100.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 544,
#     'xmin': 416,
#     'ymax': 224,
#     'ymin': 80}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00101.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 511,
#     'xmin': 390,
#     'ymax': 177,
#     'ymin': 59}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00104.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 481,
#     'xmin': 275,
#     'ymax': 218,
#     'ymin': 26}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00106.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 517,
#     'xmin': 401,
#     'ymax': 287,
#     'ymin': 152}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00107.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 294,
#     'xmin': 177,
#     'ymax': 186,
#     'ymin': 65}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00108.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 416,
#     'xmin': 270,
#     'ymax': 156,
#     'ymin': 51}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00109.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 503,
#     'xmin': 379,
#     'ymax': 216,
#     'ymin': 80}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00110.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 412,
#     'xmin': 281,
#     'ymax': 479,
#     'ymin': 32}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00111.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 572,
#     'xmin': 121,
#     'ymax': 357,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00112.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 117,
#     'xmin': 10,
#     'ymax': 197,
#     'ymin': 82}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00113.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 209,
#     'xmin': 91,
#     'ymax': 267,
#     'ymin': 144}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00114.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 383,
#     'xmin': 243,
#     'ymax': 399,
#     'ymin': 298}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00115.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 331,
#     'xmin': 225,
#     'ymax': 220,
#     'ymin': 112}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00120.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 317,
#     'xmin': 193,
#     'ymax': 381,
#     'ymin': 268}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00123.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 456,
#     'xmin': 283,
#     'ymax': 272,
#     'ymin': 116}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00124.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 461,
#     'xmin': 318,
#     'ymax': 179,
#     'ymin': 42}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00125.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 249,
#     'xmin': 137,
#     'ymax': 322,
#     'ymin': 200}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00126.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 538,
#     'xmin': 415,
#     'ymax': 100,
#     'ymin': 4}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00127.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 325,
#     'xmin': 210,
#     'ymax': 339,
#     'ymin': 228}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00130.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 378,
#     'xmin': 281,
#     'ymax': 412,
#     'ymin': 298}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00132.jpg',
#   'height': 480,
#   'object': [{'name': 'BASOPHIL',
#     'xmax': 180,
#     'xmin': 64,
#     'ymax': 257,
#     'ymin': 115}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00133.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 255,
#     'xmin': 162,
#     'ymax': 479,
#     'ymin': 401}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00134.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 636,
#     'xmin': 1,
#     'ymax': 408,
#     'ymin': 156}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00135.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 159,
#     'xmin': 65,
#     'ymax': 122,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00136.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 257,
#     'xmin': 133,
#     'ymax': 348,
#     'ymin': 213}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00137.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 389,
#     'xmin': 253,
#     'ymax': 457,
#     'ymin': 331}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00139.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 415,
#     'xmin': 180,
#     'ymax': 264,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00140.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 362,
#     'xmin': 257,
#     'ymax': 375,
#     'ymin': 259}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00141.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 279,
#     'xmin': 79,
#     'ymax': 173,
#     'ymin': 45}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00142.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 363,
#     'xmin': 257,
#     'ymax': 292,
#     'ymin': 176}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00143.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 188,
#     'xmin': 60,
#     'ymax': 426,
#     'ymin': 293}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00144.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 554,
#     'xmin': 446,
#     'ymax': 249,
#     'ymin': 133}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00145.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 434,
#     'xmin': 314,
#     'ymax': 117,
#     'ymin': 1}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00147.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 492,
#     'xmin': 355,
#     'ymax': 423,
#     'ymin': 285}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00148.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 560,
#     'xmin': 267,
#     'ymax': 282,
#     'ymin': 167}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00149.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 196,
#     'xmin': 71,
#     'ymax': 405,
#     'ymin': 283}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00150.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 383,
#     'xmin': 292,
#     'ymax': 454,
#     'ymin': 349}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00152.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 268,
#     'xmin': 145,
#     'ymax': 438,
#     'ymin': 318}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00154.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 501,
#     'xmin': 377,
#     'ymax': 468,
#     'ymin': 347}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00156.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 129,
#     'xmin': 25,
#     'ymax': 135,
#     'ymin': 14}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00157.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 355,
#     'xmin': 214,
#     'ymax': 286,
#     'ymin': 143}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00158.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 488,
#     'xmin': 352,
#     'ymax': 254,
#     'ymin': 125}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00159.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 587,
#     'xmin': 190,
#     'ymax': 335,
#     'ymin': 223}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00160.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 445,
#     'xmin': 267,
#     'ymax': 164,
#     'ymin': 12}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00161.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 363,
#     'xmin': 226,
#     'ymax': 440,
#     'ymin': 293}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00162.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 288,
#     'xmin': 136,
#     'ymax': 143,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00163.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 429,
#     'xmin': 296,
#     'ymax': 342,
#     'ymin': 226}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00164.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 640,
#     'xmin': 1,
#     'ymax': 479,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00165.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 390,
#     'xmin': 190,
#     'ymax': 407,
#     'ymin': 202}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00166.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 180,
#     'xmin': 33,
#     'ymax': 123,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00167.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 405,
#     'xmin': 255,
#     'ymax': 176,
#     'ymin': 21}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00168.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 578,
#     'xmin': 76,
#     'ymax': 310,
#     'ymin': 166}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00169.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 347,
#     'xmin': 192,
#     'ymax': 448,
#     'ymin': 308}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00170.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 350,
#     'xmin': 210,
#     'ymax': 260,
#     'ymin': 99}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00171.jpg',
#   'height': 480,
#   'object': [{'name': 'BASOPHIL',
#     'xmax': 371,
#     'xmin': 157,
#     'ymax': 479,
#     'ymin': 228}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00172.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 430,
#     'xmin': 306,
#     'ymax': 426,
#     'ymin': 273}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00174.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 372,
#     'xmin': 225,
#     'ymax': 297,
#     'ymin': 156}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00175.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 400,
#     'xmin': 250,
#     'ymax': 180,
#     'ymin': 19}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00177.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 353,
#     'xmin': 208,
#     'ymax': 366,
#     'ymin': 219}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00178.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 384,
#     'xmin': 222,
#     'ymax': 479,
#     'ymin': 343}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00179.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 431,
#     'xmin': 272,
#     'ymax': 308,
#     'ymin': 147}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00180.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 372,
#     'xmin': 183,
#     'ymax': 479,
#     'ymin': 369}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00182.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 492,
#     'xmin': 335,
#     'ymax': 378,
#     'ymin': 258}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00183.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 458,
#     'xmin': 263,
#     'ymax': 376,
#     'ymin': 193}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00184.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 272,
#     'xmin': 108,
#     'ymax': 479,
#     'ymin': 326}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00187.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 390,
#     'xmin': 186,
#     'ymax': 238,
#     'ymin': 22}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00189.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 370,
#     'xmin': 229,
#     'ymax': 299,
#     'ymin': 165}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00190.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 382,
#     'xmin': 202,
#     'ymax': 350,
#     'ymin': 177}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00191.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 554,
#     'xmin': 442,
#     'ymax': 404,
#     'ymin': 283}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00192.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 571,
#     'xmin': 464,
#     'ymax': 277,
#     'ymin': 132}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00196.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 533,
#     'xmin': 140,
#     'ymax': 416,
#     'ymin': 45}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00197.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 547,
#     'xmin': 420,
#     'ymax': 456,
#     'ymin': 333}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00198.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 570,
#     'xmin': 253,
#     'ymax': 479,
#     'ymin': 110}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00199.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 242,
#     'xmin': 112,
#     'ymax': 408,
#     'ymin': 207}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00200.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 505,
#     'xmin': 400,
#     'ymax': 203,
#     'ymin': 41}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00201.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 499,
#     'xmin': 362,
#     'ymax': 238,
#     'ymin': 67}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00202.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 574,
#     'xmin': 449,
#     'ymax': 134,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00203.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 371,
#     'xmin': 209,
#     'ymax': 182,
#     'ymin': 40}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00204.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 410,
#     'xmin': 287,
#     'ymax': 212,
#     'ymin': 59}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00205.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 323,
#     'xmin': 178,
#     'ymax': 236,
#     'ymin': 97}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00206.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 628,
#     'xmin': 491,
#     'ymax': 192,
#     'ymin': 35}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00207.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 609,
#     'xmin': 464,
#     'ymax': 159,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00208.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 454,
#     'xmin': 291,
#     'ymax': 383,
#     'ymin': 248}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00209.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 443,
#     'xmin': 318,
#     'ymax': 235,
#     'ymin': 108}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00210.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 550,
#     'xmin': 357,
#     'ymax': 111,
#     'ymin': 2}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00211.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 389,
#     'xmin': 294,
#     'ymax': 267,
#     'ymin': 177}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00212.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 511,
#     'xmin': 376,
#     'ymax': 98,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00214.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 546,
#     'xmin': 394,
#     'ymax': 409,
#     'ymin': 275}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00215.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 233,
#     'xmin': 86,
#     'ymax': 192,
#     'ymin': 37}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00216.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 440,
#     'xmin': 297,
#     'ymax': 323,
#     'ymin': 176}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00217.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 206,
#     'xmin': 96,
#     'ymax': 229,
#     'ymin': 107}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00218.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 583,
#     'xmin': 427,
#     'ymax': 241,
#     'ymin': 106}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00219.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 546,
#     'xmin': 338,
#     'ymax': 479,
#     'ymin': 249}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00220.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 457,
#     'xmin': 279,
#     'ymax': 448,
#     'ymin': 271}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00221.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 426,
#     'xmin': 282,
#     'ymax': 313,
#     'ymin': 157}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00222.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 315,
#     'xmin': 54,
#     'ymax': 426,
#     'ymin': 14}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00223.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 438,
#     'xmin': 284,
#     'ymax': 479,
#     'ymin': 329}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00224.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 367,
#     'xmin': 267,
#     'ymax': 343,
#     'ymin': 214}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00225.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 527,
#     'xmin': 271,
#     'ymax': 479,
#     'ymin': 272}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00226.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 374,
#     'xmin': 44,
#     'ymax': 369,
#     'ymin': 149}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00227.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 336,
#     'xmin': 193,
#     'ymax': 224,
#     'ymin': 51}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00228.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 422,
#     'xmin': 272,
#     'ymax': 479,
#     'ymin': 341}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00229.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 343,
#     'xmin': 210,
#     'ymax': 214,
#     'ymin': 72}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00230.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 400,
#     'xmin': 246,
#     'ymax': 398,
#     'ymin': 251}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00231.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 353,
#     'xmin': 217,
#     'ymax': 219,
#     'ymin': 77}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00232.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 166,
#     'xmin': 1,
#     'ymax': 406,
#     'ymin': 211}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00233.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 332,
#     'xmin': 129,
#     'ymax': 282,
#     'ymin': 169}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00234.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 493,
#     'xmin': 339,
#     'ymax': 276,
#     'ymin': 116}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00235.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 442,
#     'xmin': 268,
#     'ymax': 321,
#     'ymin': 167}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00236.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 640,
#     'xmin': 55,
#     'ymax': 479,
#     'ymin': 48}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00237.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 424,
#     'xmin': 272,
#     'ymax': 389,
#     'ymin': 220}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00239.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 401,
#     'xmin': 260,
#     'ymax': 185,
#     'ymin': 28}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00240.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 605,
#     'xmin': 378,
#     'ymax': 479,
#     'ymin': 293}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00241.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 428,
#     'xmin': 272,
#     'ymax': 444,
#     'ymin': 294}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00243.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 453,
#     'xmin': 306,
#     'ymax': 221,
#     'ymin': 88}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00244.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 488,
#     'xmin': 358,
#     'ymax': 408,
#     'ymin': 257}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00245.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 258,
#     'xmin': 105,
#     'ymax': 315,
#     'ymin': 138}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00246.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 326,
#     'xmin': 74,
#     'ymax': 329,
#     'ymin': 22}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00247.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 341,
#     'xmin': 211,
#     'ymax': 359,
#     'ymin': 208}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00248.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 334,
#     'xmin': 176,
#     'ymax': 229,
#     'ymin': 80}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00250.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 297,
#     'xmin': 150,
#     'ymax': 294,
#     'ymin': 162}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00251.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 508,
#     'xmin': 1,
#     'ymax': 206,
#     'ymin': 7}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00252.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 384,
#     'xmin': 234,
#     'ymax': 256,
#     'ymin': 91}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00253.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 418,
#     'xmin': 205,
#     'ymax': 104,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00254.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 373,
#     'xmin': 169,
#     'ymax': 116,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00255.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 530,
#     'xmin': 295,
#     'ymax': 427,
#     'ymin': 216}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00256.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 415,
#     'xmin': 279,
#     'ymax': 218,
#     'ymin': 75}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00257.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 370,
#     'xmin': 217,
#     'ymax': 354,
#     'ymin': 207}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00258.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 376,
#     'xmin': 245,
#     'ymax': 248,
#     'ymin': 107}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00259.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 192,
#     'xmin': 41,
#     'ymax': 278,
#     'ymin': 160}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00260.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 384,
#     'xmin': 249,
#     'ymax': 193,
#     'ymin': 21}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00261.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 442,
#     'xmin': 108,
#     'ymax': 302,
#     'ymin': 59}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00262.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 425,
#     'xmin': 179,
#     'ymax': 167,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00263.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 291,
#     'xmin': 131,
#     'ymax': 479,
#     'ymin': 356}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00264.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 349,
#     'xmin': 249,
#     'ymax': 135,
#     'ymin': 5}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00265.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 384,
#     'xmin': 251,
#     'ymax': 253,
#     'ymin': 116}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00266.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 157,
#     'xmin': 23,
#     'ymax': 210,
#     'ymin': 60}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00267.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 256,
#     'xmin': 110,
#     'ymax': 359,
#     'ymin': 202}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00268.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 305,
#     'xmin': 136,
#     'ymax': 479,
#     'ymin': 336}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00269.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 248,
#     'xmin': 113,
#     'ymax': 462,
#     'ymin': 276}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00270.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 378,
#     'xmin': 260,
#     'ymax': 118,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00271.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 374,
#     'xmin': 196,
#     'ymax': 414,
#     'ymin': 240}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00272.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 106,
#     'xmin': 1,
#     'ymax': 226,
#     'ymin': 98}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00273.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 372,
#     'xmin': 238,
#     'ymax': 479,
#     'ymin': 386}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00274.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 368,
#     'xmin': 210,
#     'ymax': 295,
#     'ymin': 130}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00275.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 405,
#     'xmin': 290,
#     'ymax': 273,
#     'ymin': 165}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00276.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 402,
#     'xmin': 257,
#     'ymax': 437,
#     'ymin': 298}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00277.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 481,
#     'xmin': 355,
#     'ymax': 283,
#     'ymin': 129}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00278.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 458,
#     'xmin': 327,
#     'ymax': 147,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00279.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 440,
#     'xmin': 293,
#     'ymax': 479,
#     'ymin': 323}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00280.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 409,
#     'xmin': 247,
#     'ymax': 172,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00281.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 422,
#     'xmin': 26,
#     'ymax': 313,
#     'ymin': 11}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00282.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 289,
#     'xmin': 198,
#     'ymax': 479,
#     'ymin': 362}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00283.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 314,
#     'xmin': 43,
#     'ymax': 392,
#     'ymin': 91}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00284.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 424,
#     'xmin': 229,
#     'ymax': 230,
#     'ymin': 44}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00285.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 354,
#     'xmin': 219,
#     'ymax': 191,
#     'ymin': 54}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00287.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 162,
#     'xmin': 33,
#     'ymax': 302,
#     'ymin': 127}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00288.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 328,
#     'xmin': 198,
#     'ymax': 169,
#     'ymin': 38}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00289.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 469,
#     'xmin': 270,
#     'ymax': 414,
#     'ymin': 194}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00290.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
# ...
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 336,
#     'xmin': 190,
#     'ymax': 251,
#     'ymin': 46}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00319.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 313,
#     'xmin': 90,
#     'ymax': 479,
#     'ymin': 280}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00320.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 304,
#     'xmin': 151,
#     'ymax': 329,
#     'ymin': 197}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00322.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 494,
#     'xmin': 337,
#     'ymax': 293,
#     'ymin': 112}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00323.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 265,
#     'xmin': 55,
#     'ymax': 356,
#     'ymin': 135}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00324.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 439,
#     'xmin': 302,
#     'ymax': 457,
#     'ymin': 318}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00325.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 296,
#     'xmin': 144,
#     'ymax': 353,
#     'ymin': 173}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00326.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 421,
#     'xmin': 242,
#     'ymax': 163,
#     'ymin': 17}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00327.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 120,
#     'xmin': 1,
#     'ymax': 290,
#     'ymin': 128}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00329.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 186,
#     'xmin': 34,
#     'ymax': 292,
#     'ymin': 181}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00330.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 640,
#     'xmin': 1,
#     'ymax': 479,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00331.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 424,
#     'xmin': 258,
#     'ymax': 438,
#     'ymin': 302}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00332.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 424,
#     'xmin': 244,
#     'ymax': 254,
#     'ymin': 82}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00333.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 511,
#     'xmin': 337,
#     'ymax': 178,
#     'ymin': 50}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00334.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 393,
#     'xmin': 263,
#     'ymax': 324,
#     'ymin': 139}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00335.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 480,
#     'xmin': 273,
#     'ymax': 114,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00336.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 495,
#     'xmin': 315,
#     'ymax': 428,
#     'ymin': 269}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00337.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 300,
#     'xmin': 158,
#     'ymax': 215,
#     'ymin': 52}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00338.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 454,
#     'xmin': 285,
#     'ymax': 103,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00339.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 412,
#     'xmin': 247,
#     'ymax': 317,
#     'ymin': 176}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00340.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 640,
#     'xmin': 1,
#     'ymax': 479,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00341.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 540,
#     'xmin': 396,
#     'ymax': 356,
#     'ymin': 214}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00342.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 351,
#     'xmin': 141,
#     'ymax': 344,
#     'ymin': 131}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00343.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 391,
#     'xmin': 210,
#     'ymax': 479,
#     'ymin': 347}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00344.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 339,
#     'xmin': 154,
#     'ymax': 353,
#     'ymin': 127}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00345.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 605,
#     'xmin': 414,
#     'ymax': 150,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00346.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 362,
#     'xmin': 202,
#     'ymax': 156,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00347.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 471,
#     'xmin': 337,
#     'ymax': 180,
#     'ymin': 34}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00348.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 282,
#     'xmin': 90,
#     'ymax': 452,
#     'ymin': 313}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00349.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 365,
#     'xmin': 217,
#     'ymax': 288,
#     'ymin': 108}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00350.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 379,
#     'xmin': 209,
#     'ymax': 183,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00351.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 562,
#     'xmin': 424,
#     'ymax': 343,
#     'ymin': 171}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00352.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 582,
#     'xmin': 362,
#     'ymax': 290,
#     'ymin': 65}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00353.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 502,
#     'xmin': 289,
#     'ymax': 286,
#     'ymin': 73}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00354.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 294,
#     'xmin': 167,
#     'ymax': 326,
#     'ymin': 142}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00355.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 544,
#     'xmin': 383,
#     'ymax': 228,
#     'ymin': 82}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00356.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 274,
#     'xmin': 139,
#     'ymax': 234,
#     'ymin': 78}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00357.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 565,
#     'xmin': 449,
#     'ymax': 247,
#     'ymin': 71}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00359.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 198,
#     'xmin': 1,
#     'ymax': 272,
#     'ymin': 74}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00360.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 458,
#     'xmin': 289,
#     'ymax': 237,
#     'ymin': 111}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00361.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 409,
#     'xmin': 241,
#     'ymax': 406,
#     'ymin': 256}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00362.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 182,
#     'xmin': 36,
#     'ymax': 106,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00364.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 516,
#     'xmin': 351,
#     'ymax': 479,
#     'ymin': 336}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00365.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 140,
#     'xmin': 1,
#     'ymax': 372,
#     'ymin': 223}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00366.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 119,
#     'xmin': 1,
#     'ymax': 371,
#     'ymin': 225}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00367.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 173,
#     'xmin': 39,
#     'ymax': 220,
#     'ymin': 70}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00368.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 113,
#     'xmin': 1,
#     'ymax': 239,
#     'ymin': 67}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00369.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 499,
#     'xmin': 356,
#     'ymax': 350,
#     'ymin': 202}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00370.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 450,
#     'xmin': 273,
#     'ymax': 310,
#     'ymin': 180}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00371.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 365,
#     'xmin': 197,
#     'ymax': 349,
#     'ymin': 229}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00372.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 319,
#     'xmin': 171,
#     'ymax': 479,
#     'ymin': 353}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00375.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 398,
#     'xmin': 252,
#     'ymax': 477,
#     'ymin': 329}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00376.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 570,
#     'xmin': 390,
#     'ymax': 192,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00377.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 262,
#     'xmin': 93,
#     'ymax': 157,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00378.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 345,
#     'xmin': 127,
#     'ymax': 232,
#     'ymin': 12}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00379.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 176,
#     'xmin': 28,
#     'ymax': 90,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00381.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 214,
#     'xmin': 71,
#     'ymax': 151,
#     'ymin': 10}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00382.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 581,
#     'xmin': 178,
#     'ymax': 440,
#     'ymin': 242}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00383.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 505,
#     'xmin': 273,
#     'ymax': 244,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00384.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 567,
#     'xmin': 411,
#     'ymax': 276,
#     'ymin': 117}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00385.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 390,
#     'xmin': 257,
#     'ymax': 142,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00386.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 354,
#     'xmin': 207,
#     'ymax': 270,
#     'ymin': 107}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00387.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 393,
#     'xmin': 219,
#     'ymax': 226,
#     'ymin': 36}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00388.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 223,
#     'xmin': 74,
#     'ymax': 479,
#     'ymin': 384}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00389.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 209,
#     'xmin': 11,
#     'ymax': 450,
#     'ymin': 324}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00390.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 339,
#     'xmin': 183,
#     'ymax': 170,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00391.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 376,
#     'xmin': 235,
#     'ymax': 261,
#     'ymin': 100}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00392.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 333,
#     'xmin': 160,
#     'ymax': 399,
#     'ymin': 208}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00393.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 387,
#     'xmin': 230,
#     'ymax': 358,
#     'ymin': 199}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00395.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 535,
#     'xmin': 132,
#     'ymax': 395,
#     'ymin': 198}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00396.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 480,
#     'xmin': 260,
#     'ymax': 324,
#     'ymin': 5}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00397.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 640,
#     'xmin': 1,
#     'ymax': 479,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00398.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 371,
#     'xmin': 205,
#     'ymax': 418,
#     'ymin': 251}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00400.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 300,
#     'xmin': 127,
#     'ymax': 454,
#     'ymin': 266}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00402.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 624,
#     'xmin': 498,
#     'ymax': 196,
#     'ymin': 42}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00403.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 608,
#     'xmin': 106,
#     'ymax': 477,
#     'ymin': 122}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00404.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 269,
#     'xmin': 135,
#     'ymax': 320,
#     'ymin': 143}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00405.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 495,
#     'xmin': 365,
#     'ymax': 204,
#     'ymin': 62}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00407.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 640,
#     'xmin': 434,
#     'ymax': 240,
#     'ymin': 4}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00408.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 532,
#     'xmin': 373,
#     'ymax': 142,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00409.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 255,
#     'xmin': 93,
#     'ymax': 167,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00410.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 573,
#     'xmin': 395,
#     'ymax': 261,
#     'ymin': 99}],
#   'width': 640}]

# %%
seen_labels
# Out:
# {'BASOPHIL': 3,
#  'EOSINOPHIL': 88,
#  'LYMPHOCYTE': 33,
#  'MONOCYTE': 20,
#  'NEUTROPHIL': 207}

# %%
#for img in all_imgs:
#    img['filename'] = img['filename'] + '.jpg'

# %%
all_imgs
# Out:
# [{'filename': 'dataset/JPEGImages/BloodImage_00000.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 484,
#     'xmin': 281,
#     'ymax': 299,
#     'ymin': 126}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00001.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 265,
#     'xmin': 100,
#     'ymax': 149,
#     'ymin': 10}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00002.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 507,
#     'xmin': 337,
#     'ymax': 479,
#     'ymin': 384}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00003.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 319,
#     'xmin': 151,
#     'ymax': 424,
#     'ymin': 273}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00004.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 317,
#     'xmin': 148,
#     'ymax': 318,
#     'ymin': 171}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00005.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 435,
#     'xmin': 247,
#     'ymax': 149,
#     'ymin': 11}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00006.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 279,
#     'xmin': 134,
#     'ymax': 289,
#     'ymin': 139}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00007.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 396,
#     'xmin': 253,
#     'ymax': 382,
#     'ymin': 235}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00008.jpg',
#   'height': 480,
#   'object': [{'name': 'BASOPHIL',
#     'xmax': 272,
#     'xmin': 61,
#     'ymax': 297,
#     'ymin': 97}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00009.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 253,
#     'xmin': 26,
#     'ymax': 316,
#     'ymin': 58}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00011.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 270,
#     'xmin': 132,
#     'ymax': 346,
#     'ymin': 164}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00012.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 199,
#     'xmin': 48,
#     'ymax': 276,
#     'ymin': 131}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00013.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 196,
#     'xmin': 55,
#     'ymax': 248,
#     'ymin': 106}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00014.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 371,
#     'xmin': 252,
#     'ymax': 249,
#     'ymin': 135}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00015.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 360,
#     'xmin': 157,
#     'ymax': 463,
#     'ymin': 260}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00016.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 303,
#     'xmin': 172,
#     'ymax': 328,
#     'ymin': 224}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00017.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 314,
#     'xmin': 143,
#     'ymax': 233,
#     'ymin': 121}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00018.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 468,
#     'xmin': 341,
#     'ymax': 458,
#     'ymin': 345}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00019.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 280,
#     'xmin': 131,
#     'ymax': 359,
#     'ymin': 222}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00020.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 462,
#     'xmin': 367,
#     'ymax': 111,
#     'ymin': 35}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00021.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 462,
#     'xmin': 348,
#     'ymax': 166,
#     'ymin': 52}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00022.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 262,
#     'xmin': 148,
#     'ymax': 255,
#     'ymin': 130}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00023.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 255,
#     'xmin': 127,
#     'ymax': 422,
#     'ymin': 297}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00024.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 463,
#     'xmin': 330,
#     'ymax': 479,
#     'ymin': 387}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00026.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 561,
#     'xmin': 408,
#     'ymax': 479,
#     'ymin': 380}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00028.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 421,
#     'xmin': 273,
#     'ymax': 479,
#     'ymin': 331}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00029.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 196,
#     'xmin': 87,
#     'ymax': 294,
#     'ymin': 176}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00030.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 123,
#     'xmin': 16,
#     'ymax': 274,
#     'ymin': 157}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00032.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 272,
#     'xmin': 167,
#     'ymax': 401,
#     'ymin': 289}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00033.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 275,
#     'xmin': 164,
#     'ymax': 360,
#     'ymin': 245}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00035.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 313,
#     'xmin': 210,
#     'ymax': 186,
#     'ymin': 76}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00036.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 257,
#     'xmin': 121,
#     'ymax': 226,
#     'ymin': 66}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00037.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 525,
#     'xmin': 434,
#     'ymax': 168,
#     'ymin': 71}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00038.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 532,
#     'xmin': 440,
#     'ymax': 169,
#     'ymin': 69}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00039.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 228,
#     'xmin': 125,
#     'ymax': 260,
#     'ymin': 142}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00040.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 436,
#     'xmin': 1,
#     'ymax': 339,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00041.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 640,
#     'xmin': 284,
#     'ymax': 479,
#     'ymin': 124}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00042.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 261,
#     'xmin': 150,
#     'ymax': 272,
#     'ymin': 170}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00045.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 619,
#     'xmin': 495,
#     'ymax': 442,
#     'ymin': 352}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00046.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 426,
#     'xmin': 332,
#     'ymax': 479,
#     'ymin': 395}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00047.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 379,
#     'xmin': 284,
#     'ymax': 328,
#     'ymin': 230}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00048.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 332,
#     'xmin': 211,
#     'ymax': 316,
#     'ymin': 194}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00049.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 272,
#     'xmin': 169,
#     'ymax': 226,
#     'ymin': 127}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00050.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 303,
#     'xmin': 180,
#     'ymax': 473,
#     'ymin': 379}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00052.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 242,
#     'xmin': 124,
#     'ymax': 232,
#     'ymin': 145}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00053.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 225,
#     'xmin': 118,
#     'ymax': 457,
#     'ymin': 352}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00054.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 253,
#     'xmin': 164,
#     'ymax': 406,
#     'ymin': 323}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00055.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 260,
#     'xmin': 171,
#     'ymax': 329,
#     'ymin': 245}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00056.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 379,
#     'xmin': 291,
#     'ymax': 242,
#     'ymin': 134}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00057.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 298,
#     'xmin': 188,
#     'ymax': 389,
#     'ymin': 286}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00058.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 330,
#     'xmin': 225,
#     'ymax': 472,
#     'ymin': 366}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00059.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 320,
#     'xmin': 217,
#     'ymax': 304,
#     'ymin': 193}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00062.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 233,
#     'xmin': 104,
#     'ymax': 213,
#     'ymin': 92}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00063.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 476,
#     'xmin': 378,
#     'ymax': 167,
#     'ymin': 66}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00064.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 153,
#     'xmin': 50,
#     'ymax': 342,
#     'ymin': 246}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00066.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 569,
#     'xmin': 453,
#     'ymax': 272,
#     'ymin': 161}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00067.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 243,
#     'xmin': 149,
#     'ymax': 128,
#     'ymin': 11}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00068.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 84,
#     'xmin': 1,
#     'ymax': 246,
#     'ymin': 143}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00069.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 476,
#     'xmin': 358,
#     'ymax': 217,
#     'ymin': 106}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00071.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 280,
#     'xmin': 192,
#     'ymax': 118,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00072.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 301,
#     'xmin': 208,
#     'ymax': 186,
#     'ymin': 88}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00073.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 333,
#     'xmin': 227,
#     'ymax': 424,
#     'ymin': 333}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00074.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 116,
#     'xmin': 29,
#     'ymax': 455,
#     'ymin': 356}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00075.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 317,
#     'xmin': 180,
#     'ymax': 466,
#     'ymin': 378}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00076.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 208,
#     'xmin': 112,
#     'ymax': 242,
#     'ymin': 137}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00077.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 282,
#     'xmin': 160,
#     'ymax': 375,
#     'ymin': 284}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00078.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 231,
#     'xmin': 129,
#     'ymax': 163,
#     'ymin': 45}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00079.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 103,
#     'xmin': 1,
#     'ymax': 276,
#     'ymin': 172}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00081.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 430,
#     'xmin': 314,
#     'ymax': 120,
#     'ymin': 37}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00082.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 369,
#     'xmin': 279,
#     'ymax': 131,
#     'ymin': 27}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00083.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 476,
#     'xmin': 104,
#     'ymax': 456,
#     'ymin': 94}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00086.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 186,
#     'xmin': 82,
#     'ymax': 345,
#     'ymin': 249}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00087.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 288,
#     'xmin': 201,
#     'ymax': 255,
#     'ymin': 162}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00088.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 367,
#     'xmin': 270,
#     'ymax': 247,
#     'ymin': 130}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00089.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 444,
#     'xmin': 316,
#     'ymax': 241,
#     'ymin': 112}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00090.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 352,
#     'xmin': 255,
#     'ymax': 207,
#     'ymin': 115}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00091.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 325,
#     'xmin': 234,
#     'ymax': 471,
#     'ymin': 367}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00092.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 400,
#     'xmin': 298,
#     'ymax': 424,
#     'ymin': 324}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00093.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 134,
#     'xmin': 30,
#     'ymax': 479,
#     'ymin': 392}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00094.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 530,
#     'xmin': 308,
#     'ymax': 356,
#     'ymin': 161}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00095.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 406,
#     'xmin': 200,
#     'ymax': 479,
#     'ymin': 300}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00096.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 575,
#     'xmin': 182,
#     'ymax': 411,
#     'ymin': 192}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00097.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 516,
#     'xmin': 294,
#     'ymax': 379,
#     'ymin': 198}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00098.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 339,
#     'xmin': 187,
#     'ymax': 331,
#     'ymin': 193}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00099.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 370,
#     'xmin': 232,
#     'ymax': 243,
#     'ymin': 143}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00100.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 544,
#     'xmin': 416,
#     'ymax': 224,
#     'ymin': 80}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00101.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 511,
#     'xmin': 390,
#     'ymax': 177,
#     'ymin': 59}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00104.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 481,
#     'xmin': 275,
#     'ymax': 218,
#     'ymin': 26}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00106.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 517,
#     'xmin': 401,
#     'ymax': 287,
#     'ymin': 152}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00107.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 294,
#     'xmin': 177,
#     'ymax': 186,
#     'ymin': 65}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00108.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 416,
#     'xmin': 270,
#     'ymax': 156,
#     'ymin': 51}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00109.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 503,
#     'xmin': 379,
#     'ymax': 216,
#     'ymin': 80}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00110.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 412,
#     'xmin': 281,
#     'ymax': 479,
#     'ymin': 32}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00111.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 572,
#     'xmin': 121,
#     'ymax': 357,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00112.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 117,
#     'xmin': 10,
#     'ymax': 197,
#     'ymin': 82}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00113.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 209,
#     'xmin': 91,
#     'ymax': 267,
#     'ymin': 144}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00114.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 383,
#     'xmin': 243,
#     'ymax': 399,
#     'ymin': 298}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00115.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 331,
#     'xmin': 225,
#     'ymax': 220,
#     'ymin': 112}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00120.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 317,
#     'xmin': 193,
#     'ymax': 381,
#     'ymin': 268}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00123.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 456,
#     'xmin': 283,
#     'ymax': 272,
#     'ymin': 116}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00124.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 461,
#     'xmin': 318,
#     'ymax': 179,
#     'ymin': 42}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00125.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 249,
#     'xmin': 137,
#     'ymax': 322,
#     'ymin': 200}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00126.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 538,
#     'xmin': 415,
#     'ymax': 100,
#     'ymin': 4}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00127.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 325,
#     'xmin': 210,
#     'ymax': 339,
#     'ymin': 228}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00130.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 378,
#     'xmin': 281,
#     'ymax': 412,
#     'ymin': 298}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00132.jpg',
#   'height': 480,
#   'object': [{'name': 'BASOPHIL',
#     'xmax': 180,
#     'xmin': 64,
#     'ymax': 257,
#     'ymin': 115}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00133.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 255,
#     'xmin': 162,
#     'ymax': 479,
#     'ymin': 401}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00134.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 636,
#     'xmin': 1,
#     'ymax': 408,
#     'ymin': 156}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00135.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 159,
#     'xmin': 65,
#     'ymax': 122,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00136.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 257,
#     'xmin': 133,
#     'ymax': 348,
#     'ymin': 213}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00137.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 389,
#     'xmin': 253,
#     'ymax': 457,
#     'ymin': 331}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00139.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 415,
#     'xmin': 180,
#     'ymax': 264,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00140.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 362,
#     'xmin': 257,
#     'ymax': 375,
#     'ymin': 259}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00141.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 279,
#     'xmin': 79,
#     'ymax': 173,
#     'ymin': 45}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00142.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 363,
#     'xmin': 257,
#     'ymax': 292,
#     'ymin': 176}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00143.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 188,
#     'xmin': 60,
#     'ymax': 426,
#     'ymin': 293}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00144.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 554,
#     'xmin': 446,
#     'ymax': 249,
#     'ymin': 133}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00145.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 434,
#     'xmin': 314,
#     'ymax': 117,
#     'ymin': 1}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00147.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 492,
#     'xmin': 355,
#     'ymax': 423,
#     'ymin': 285}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00148.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 560,
#     'xmin': 267,
#     'ymax': 282,
#     'ymin': 167}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00149.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 196,
#     'xmin': 71,
#     'ymax': 405,
#     'ymin': 283}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00150.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 383,
#     'xmin': 292,
#     'ymax': 454,
#     'ymin': 349}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00152.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 268,
#     'xmin': 145,
#     'ymax': 438,
#     'ymin': 318}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00154.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 501,
#     'xmin': 377,
#     'ymax': 468,
#     'ymin': 347}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00156.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 129,
#     'xmin': 25,
#     'ymax': 135,
#     'ymin': 14}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00157.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 355,
#     'xmin': 214,
#     'ymax': 286,
#     'ymin': 143}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00158.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 488,
#     'xmin': 352,
#     'ymax': 254,
#     'ymin': 125}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00159.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 587,
#     'xmin': 190,
#     'ymax': 335,
#     'ymin': 223}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00160.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 445,
#     'xmin': 267,
#     'ymax': 164,
#     'ymin': 12}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00161.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 363,
#     'xmin': 226,
#     'ymax': 440,
#     'ymin': 293}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00162.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 288,
#     'xmin': 136,
#     'ymax': 143,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00163.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 429,
#     'xmin': 296,
#     'ymax': 342,
#     'ymin': 226}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00164.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 640,
#     'xmin': 1,
#     'ymax': 479,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00165.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 390,
#     'xmin': 190,
#     'ymax': 407,
#     'ymin': 202}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00166.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 180,
#     'xmin': 33,
#     'ymax': 123,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00167.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 405,
#     'xmin': 255,
#     'ymax': 176,
#     'ymin': 21}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00168.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 578,
#     'xmin': 76,
#     'ymax': 310,
#     'ymin': 166}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00169.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 347,
#     'xmin': 192,
#     'ymax': 448,
#     'ymin': 308}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00170.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 350,
#     'xmin': 210,
#     'ymax': 260,
#     'ymin': 99}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00171.jpg',
#   'height': 480,
#   'object': [{'name': 'BASOPHIL',
#     'xmax': 371,
#     'xmin': 157,
#     'ymax': 479,
#     'ymin': 228}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00172.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 430,
#     'xmin': 306,
#     'ymax': 426,
#     'ymin': 273}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00174.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 372,
#     'xmin': 225,
#     'ymax': 297,
#     'ymin': 156}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00175.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 400,
#     'xmin': 250,
#     'ymax': 180,
#     'ymin': 19}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00177.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 353,
#     'xmin': 208,
#     'ymax': 366,
#     'ymin': 219}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00178.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 384,
#     'xmin': 222,
#     'ymax': 479,
#     'ymin': 343}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00179.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 431,
#     'xmin': 272,
#     'ymax': 308,
#     'ymin': 147}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00180.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 372,
#     'xmin': 183,
#     'ymax': 479,
#     'ymin': 369}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00182.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 492,
#     'xmin': 335,
#     'ymax': 378,
#     'ymin': 258}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00183.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 458,
#     'xmin': 263,
#     'ymax': 376,
#     'ymin': 193}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00184.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 272,
#     'xmin': 108,
#     'ymax': 479,
#     'ymin': 326}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00187.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 390,
#     'xmin': 186,
#     'ymax': 238,
#     'ymin': 22}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00189.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 370,
#     'xmin': 229,
#     'ymax': 299,
#     'ymin': 165}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00190.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 382,
#     'xmin': 202,
#     'ymax': 350,
#     'ymin': 177}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00191.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 554,
#     'xmin': 442,
#     'ymax': 404,
#     'ymin': 283}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00192.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 571,
#     'xmin': 464,
#     'ymax': 277,
#     'ymin': 132}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00196.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 533,
#     'xmin': 140,
#     'ymax': 416,
#     'ymin': 45}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00197.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 547,
#     'xmin': 420,
#     'ymax': 456,
#     'ymin': 333}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00198.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 570,
#     'xmin': 253,
#     'ymax': 479,
#     'ymin': 110}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00199.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 242,
#     'xmin': 112,
#     'ymax': 408,
#     'ymin': 207}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00200.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 505,
#     'xmin': 400,
#     'ymax': 203,
#     'ymin': 41}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00201.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 499,
#     'xmin': 362,
#     'ymax': 238,
#     'ymin': 67}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00202.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 574,
#     'xmin': 449,
#     'ymax': 134,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00203.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 371,
#     'xmin': 209,
#     'ymax': 182,
#     'ymin': 40}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00204.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 410,
#     'xmin': 287,
#     'ymax': 212,
#     'ymin': 59}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00205.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 323,
#     'xmin': 178,
#     'ymax': 236,
#     'ymin': 97}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00206.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 628,
#     'xmin': 491,
#     'ymax': 192,
#     'ymin': 35}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00207.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 609,
#     'xmin': 464,
#     'ymax': 159,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00208.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 454,
#     'xmin': 291,
#     'ymax': 383,
#     'ymin': 248}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00209.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 443,
#     'xmin': 318,
#     'ymax': 235,
#     'ymin': 108}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00210.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 550,
#     'xmin': 357,
#     'ymax': 111,
#     'ymin': 2}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00211.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 389,
#     'xmin': 294,
#     'ymax': 267,
#     'ymin': 177}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00212.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 511,
#     'xmin': 376,
#     'ymax': 98,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00214.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 546,
#     'xmin': 394,
#     'ymax': 409,
#     'ymin': 275}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00215.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 233,
#     'xmin': 86,
#     'ymax': 192,
#     'ymin': 37}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00216.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 440,
#     'xmin': 297,
#     'ymax': 323,
#     'ymin': 176}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00217.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 206,
#     'xmin': 96,
#     'ymax': 229,
#     'ymin': 107}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00218.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 583,
#     'xmin': 427,
#     'ymax': 241,
#     'ymin': 106}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00219.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 546,
#     'xmin': 338,
#     'ymax': 479,
#     'ymin': 249}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00220.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 457,
#     'xmin': 279,
#     'ymax': 448,
#     'ymin': 271}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00221.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 426,
#     'xmin': 282,
#     'ymax': 313,
#     'ymin': 157}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00222.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 315,
#     'xmin': 54,
#     'ymax': 426,
#     'ymin': 14}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00223.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 438,
#     'xmin': 284,
#     'ymax': 479,
#     'ymin': 329}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00224.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 367,
#     'xmin': 267,
#     'ymax': 343,
#     'ymin': 214}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00225.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 527,
#     'xmin': 271,
#     'ymax': 479,
#     'ymin': 272}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00226.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 374,
#     'xmin': 44,
#     'ymax': 369,
#     'ymin': 149}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00227.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 336,
#     'xmin': 193,
#     'ymax': 224,
#     'ymin': 51}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00228.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 422,
#     'xmin': 272,
#     'ymax': 479,
#     'ymin': 341}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00229.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 343,
#     'xmin': 210,
#     'ymax': 214,
#     'ymin': 72}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00230.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 400,
#     'xmin': 246,
#     'ymax': 398,
#     'ymin': 251}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00231.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 353,
#     'xmin': 217,
#     'ymax': 219,
#     'ymin': 77}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00232.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 166,
#     'xmin': 1,
#     'ymax': 406,
#     'ymin': 211}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00233.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 332,
#     'xmin': 129,
#     'ymax': 282,
#     'ymin': 169}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00234.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 493,
#     'xmin': 339,
#     'ymax': 276,
#     'ymin': 116}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00235.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 442,
#     'xmin': 268,
#     'ymax': 321,
#     'ymin': 167}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00236.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 640,
#     'xmin': 55,
#     'ymax': 479,
#     'ymin': 48}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00237.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 424,
#     'xmin': 272,
#     'ymax': 389,
#     'ymin': 220}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00239.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 401,
#     'xmin': 260,
#     'ymax': 185,
#     'ymin': 28}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00240.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 605,
#     'xmin': 378,
#     'ymax': 479,
#     'ymin': 293}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00241.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 428,
#     'xmin': 272,
#     'ymax': 444,
#     'ymin': 294}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00243.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 453,
#     'xmin': 306,
#     'ymax': 221,
#     'ymin': 88}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00244.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 488,
#     'xmin': 358,
#     'ymax': 408,
#     'ymin': 257}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00245.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 258,
#     'xmin': 105,
#     'ymax': 315,
#     'ymin': 138}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00246.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 326,
#     'xmin': 74,
#     'ymax': 329,
#     'ymin': 22}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00247.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 341,
#     'xmin': 211,
#     'ymax': 359,
#     'ymin': 208}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00248.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 334,
#     'xmin': 176,
#     'ymax': 229,
#     'ymin': 80}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00250.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 297,
#     'xmin': 150,
#     'ymax': 294,
#     'ymin': 162}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00251.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 508,
#     'xmin': 1,
#     'ymax': 206,
#     'ymin': 7}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00252.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 384,
#     'xmin': 234,
#     'ymax': 256,
#     'ymin': 91}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00253.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 418,
#     'xmin': 205,
#     'ymax': 104,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00254.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 373,
#     'xmin': 169,
#     'ymax': 116,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00255.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 530,
#     'xmin': 295,
#     'ymax': 427,
#     'ymin': 216}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00256.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 415,
#     'xmin': 279,
#     'ymax': 218,
#     'ymin': 75}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00257.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 370,
#     'xmin': 217,
#     'ymax': 354,
#     'ymin': 207}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00258.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 376,
#     'xmin': 245,
#     'ymax': 248,
#     'ymin': 107}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00259.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 192,
#     'xmin': 41,
#     'ymax': 278,
#     'ymin': 160}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00260.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 384,
#     'xmin': 249,
#     'ymax': 193,
#     'ymin': 21}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00261.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 442,
#     'xmin': 108,
#     'ymax': 302,
#     'ymin': 59}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00262.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 425,
#     'xmin': 179,
#     'ymax': 167,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00263.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 291,
#     'xmin': 131,
#     'ymax': 479,
#     'ymin': 356}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00264.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 349,
#     'xmin': 249,
#     'ymax': 135,
#     'ymin': 5}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00265.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 384,
#     'xmin': 251,
#     'ymax': 253,
#     'ymin': 116}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00266.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 157,
#     'xmin': 23,
#     'ymax': 210,
#     'ymin': 60}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00267.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 256,
#     'xmin': 110,
#     'ymax': 359,
#     'ymin': 202}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00268.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 305,
#     'xmin': 136,
#     'ymax': 479,
#     'ymin': 336}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00269.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 248,
#     'xmin': 113,
#     'ymax': 462,
#     'ymin': 276}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00270.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 378,
#     'xmin': 260,
#     'ymax': 118,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00271.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 374,
#     'xmin': 196,
#     'ymax': 414,
#     'ymin': 240}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00272.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 106,
#     'xmin': 1,
#     'ymax': 226,
#     'ymin': 98}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00273.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 372,
#     'xmin': 238,
#     'ymax': 479,
#     'ymin': 386}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00274.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 368,
#     'xmin': 210,
#     'ymax': 295,
#     'ymin': 130}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00275.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 405,
#     'xmin': 290,
#     'ymax': 273,
#     'ymin': 165}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00276.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 402,
#     'xmin': 257,
#     'ymax': 437,
#     'ymin': 298}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00277.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 481,
#     'xmin': 355,
#     'ymax': 283,
#     'ymin': 129}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00278.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 458,
#     'xmin': 327,
#     'ymax': 147,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00279.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 440,
#     'xmin': 293,
#     'ymax': 479,
#     'ymin': 323}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00280.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 409,
#     'xmin': 247,
#     'ymax': 172,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00281.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 422,
#     'xmin': 26,
#     'ymax': 313,
#     'ymin': 11}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00282.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 289,
#     'xmin': 198,
#     'ymax': 479,
#     'ymin': 362}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00283.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 314,
#     'xmin': 43,
#     'ymax': 392,
#     'ymin': 91}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00284.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 424,
#     'xmin': 229,
#     'ymax': 230,
#     'ymin': 44}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00285.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 354,
#     'xmin': 219,
#     'ymax': 191,
#     'ymin': 54}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00287.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 162,
#     'xmin': 33,
#     'ymax': 302,
#     'ymin': 127}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00288.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 328,
#     'xmin': 198,
#     'ymax': 169,
#     'ymin': 38}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00289.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 469,
#     'xmin': 270,
#     'ymax': 414,
#     'ymin': 194}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00290.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
# ...
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 336,
#     'xmin': 190,
#     'ymax': 251,
#     'ymin': 46}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00319.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 313,
#     'xmin': 90,
#     'ymax': 479,
#     'ymin': 280}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00320.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 304,
#     'xmin': 151,
#     'ymax': 329,
#     'ymin': 197}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00322.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 494,
#     'xmin': 337,
#     'ymax': 293,
#     'ymin': 112}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00323.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 265,
#     'xmin': 55,
#     'ymax': 356,
#     'ymin': 135}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00324.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 439,
#     'xmin': 302,
#     'ymax': 457,
#     'ymin': 318}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00325.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 296,
#     'xmin': 144,
#     'ymax': 353,
#     'ymin': 173}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00326.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 421,
#     'xmin': 242,
#     'ymax': 163,
#     'ymin': 17}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00327.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 120,
#     'xmin': 1,
#     'ymax': 290,
#     'ymin': 128}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00329.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 186,
#     'xmin': 34,
#     'ymax': 292,
#     'ymin': 181}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00330.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 640,
#     'xmin': 1,
#     'ymax': 479,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00331.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 424,
#     'xmin': 258,
#     'ymax': 438,
#     'ymin': 302}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00332.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 424,
#     'xmin': 244,
#     'ymax': 254,
#     'ymin': 82}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00333.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 511,
#     'xmin': 337,
#     'ymax': 178,
#     'ymin': 50}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00334.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 393,
#     'xmin': 263,
#     'ymax': 324,
#     'ymin': 139}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00335.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 480,
#     'xmin': 273,
#     'ymax': 114,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00336.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 495,
#     'xmin': 315,
#     'ymax': 428,
#     'ymin': 269}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00337.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 300,
#     'xmin': 158,
#     'ymax': 215,
#     'ymin': 52}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00338.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 454,
#     'xmin': 285,
#     'ymax': 103,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00339.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 412,
#     'xmin': 247,
#     'ymax': 317,
#     'ymin': 176}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00340.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 640,
#     'xmin': 1,
#     'ymax': 479,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00341.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 540,
#     'xmin': 396,
#     'ymax': 356,
#     'ymin': 214}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00342.jpg',
#   'height': 480,
#   'object': [{'name': 'MONOCYTE',
#     'xmax': 351,
#     'xmin': 141,
#     'ymax': 344,
#     'ymin': 131}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00343.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 391,
#     'xmin': 210,
#     'ymax': 479,
#     'ymin': 347}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00344.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 339,
#     'xmin': 154,
#     'ymax': 353,
#     'ymin': 127}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00345.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 605,
#     'xmin': 414,
#     'ymax': 150,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00346.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 362,
#     'xmin': 202,
#     'ymax': 156,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00347.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 471,
#     'xmin': 337,
#     'ymax': 180,
#     'ymin': 34}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00348.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 282,
#     'xmin': 90,
#     'ymax': 452,
#     'ymin': 313}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00349.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 365,
#     'xmin': 217,
#     'ymax': 288,
#     'ymin': 108}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00350.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 379,
#     'xmin': 209,
#     'ymax': 183,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00351.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 562,
#     'xmin': 424,
#     'ymax': 343,
#     'ymin': 171}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00352.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 582,
#     'xmin': 362,
#     'ymax': 290,
#     'ymin': 65}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00353.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 502,
#     'xmin': 289,
#     'ymax': 286,
#     'ymin': 73}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00354.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 294,
#     'xmin': 167,
#     'ymax': 326,
#     'ymin': 142}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00355.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 544,
#     'xmin': 383,
#     'ymax': 228,
#     'ymin': 82}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00356.jpg',
#   'height': 480,
#   'object': [{'name': 'LYMPHOCYTE',
#     'xmax': 274,
#     'xmin': 139,
#     'ymax': 234,
#     'ymin': 78}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00357.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 565,
#     'xmin': 449,
#     'ymax': 247,
#     'ymin': 71}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00359.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 198,
#     'xmin': 1,
#     'ymax': 272,
#     'ymin': 74}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00360.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 458,
#     'xmin': 289,
#     'ymax': 237,
#     'ymin': 111}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00361.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 409,
#     'xmin': 241,
#     'ymax': 406,
#     'ymin': 256}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00362.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 182,
#     'xmin': 36,
#     'ymax': 106,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00364.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 516,
#     'xmin': 351,
#     'ymax': 479,
#     'ymin': 336}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00365.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 140,
#     'xmin': 1,
#     'ymax': 372,
#     'ymin': 223}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00366.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 119,
#     'xmin': 1,
#     'ymax': 371,
#     'ymin': 225}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00367.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 173,
#     'xmin': 39,
#     'ymax': 220,
#     'ymin': 70}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00368.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 113,
#     'xmin': 1,
#     'ymax': 239,
#     'ymin': 67}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00369.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 499,
#     'xmin': 356,
#     'ymax': 350,
#     'ymin': 202}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00370.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 450,
#     'xmin': 273,
#     'ymax': 310,
#     'ymin': 180}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00371.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 365,
#     'xmin': 197,
#     'ymax': 349,
#     'ymin': 229}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00372.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 319,
#     'xmin': 171,
#     'ymax': 479,
#     'ymin': 353}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00375.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 398,
#     'xmin': 252,
#     'ymax': 477,
#     'ymin': 329}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00376.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 570,
#     'xmin': 390,
#     'ymax': 192,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00377.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 262,
#     'xmin': 93,
#     'ymax': 157,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00378.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 345,
#     'xmin': 127,
#     'ymax': 232,
#     'ymin': 12}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00379.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 176,
#     'xmin': 28,
#     'ymax': 90,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00381.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 214,
#     'xmin': 71,
#     'ymax': 151,
#     'ymin': 10}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00382.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 581,
#     'xmin': 178,
#     'ymax': 440,
#     'ymin': 242}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00383.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 505,
#     'xmin': 273,
#     'ymax': 244,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00384.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 567,
#     'xmin': 411,
#     'ymax': 276,
#     'ymin': 117}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00385.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 390,
#     'xmin': 257,
#     'ymax': 142,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00386.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 354,
#     'xmin': 207,
#     'ymax': 270,
#     'ymin': 107}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00387.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 393,
#     'xmin': 219,
#     'ymax': 226,
#     'ymin': 36}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00388.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 223,
#     'xmin': 74,
#     'ymax': 479,
#     'ymin': 384}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00389.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 209,
#     'xmin': 11,
#     'ymax': 450,
#     'ymin': 324}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00390.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 339,
#     'xmin': 183,
#     'ymax': 170,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00391.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 376,
#     'xmin': 235,
#     'ymax': 261,
#     'ymin': 100}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00392.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 333,
#     'xmin': 160,
#     'ymax': 399,
#     'ymin': 208}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00393.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 387,
#     'xmin': 230,
#     'ymax': 358,
#     'ymin': 199}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00395.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 535,
#     'xmin': 132,
#     'ymax': 395,
#     'ymin': 198}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00396.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 480,
#     'xmin': 260,
#     'ymax': 324,
#     'ymin': 5}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00397.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 640,
#     'xmin': 1,
#     'ymax': 479,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00398.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 371,
#     'xmin': 205,
#     'ymax': 418,
#     'ymin': 251}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00400.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 300,
#     'xmin': 127,
#     'ymax': 454,
#     'ymin': 266}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00402.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 624,
#     'xmin': 498,
#     'ymax': 196,
#     'ymin': 42}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00403.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 608,
#     'xmin': 106,
#     'ymax': 477,
#     'ymin': 122}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00404.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 269,
#     'xmin': 135,
#     'ymax': 320,
#     'ymin': 143}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00405.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 495,
#     'xmin': 365,
#     'ymax': 204,
#     'ymin': 62}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00407.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 640,
#     'xmin': 434,
#     'ymax': 240,
#     'ymin': 4}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00408.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 532,
#     'xmin': 373,
#     'ymax': 142,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00409.jpg',
#   'height': 480,
#   'object': [{'name': 'NEUTROPHIL',
#     'xmax': 255,
#     'xmin': 93,
#     'ymax': 167,
#     'ymin': 0}],
#   'width': 640},
#  {'filename': 'dataset/JPEGImages/BloodImage_00410.jpg',
#   'height': 480,
#   'object': [{'name': 'EOSINOPHIL',
#     'xmax': 573,
#     'xmin': 395,
#     'ymax': 261,
#     'ymin': 99}],
#   'width': 640}]

# %%
batches = BatchGenerator(all_imgs, generator_config)
# Out:
# Entered generator
# {'object': [{'xmin': 281, 'ymax': 299, 'xmax': 484, 'name': 'NEUTROPHIL', 'ymin': 126}], 'height': 480, 'filename': 'dataset/JPEGImages/BloodImage_00000.jpg', 'width': 640}

# %%
image=batches.load_image(5)

# %%
#image = batches[0][0][0][0]
plt.imshow(image)

# %%
def normalize(image):
    return image/255.

train_valid_split = int(0.8*len(all_imgs))

train_batch = BatchGenerator(all_imgs[:train_valid_split], generator_config)
valid_batch = BatchGenerator(all_imgs[train_valid_split:], generator_config, norm=normalize)
# Out:
# Entered generator
# {'object': [{'xmin': 1, 'ymax': 290, 'xmax': 120, 'name': 'NEUTROPHIL', 'ymin': 128}], 'height': 480, 'filename': 'dataset/JPEGImages/BloodImage_00327.jpg', 'width': 640}
# Entered generator
# {'object': [{'xmin': 285, 'ymax': 103, 'xmax': 454, 'name': 'NEUTROPHIL', 'ymin': 0}], 'height': 480, 'filename': 'dataset/JPEGImages/BloodImage_00338.jpg', 'width': 640}

# %%
train_batch.size()
# Out:
# 280

# %%
valid_batch.size()
# Out:
# 71

# %%
def space_to_depth_x2(x):
    return tf.space_to_depth(x, block_size=2)

# %%
input_image = Input(shape=(IMAGE_H, IMAGE_W, 3))
true_boxes  = Input(shape=(1, 1, 1, TRUE_BOX_BUFFER , 4))

# %%
# Layer 1
x = Conv2D(32, (3,3), strides=(1,1), padding='same', name='conv_1', use_bias=False)(input_image)
x = BatchNormalization(name='norm_1')(x)
x = LeakyReLU(alpha=0.1)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 2
x = Conv2D(64, (3,3), strides=(1,1), padding='same', name='conv_2', use_bias=False)(x)
x = BatchNormalization(name='norm_2')(x)
x = LeakyReLU(alpha=0.1)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 3
x = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_3', use_bias=False)(x)
x = BatchNormalization(name='norm_3')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 4
x = Conv2D(64, (1,1), strides=(1,1), padding='same', name='conv_4', use_bias=False)(x)
x = BatchNormalization(name='norm_4')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 5
x = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_5', use_bias=False)(x)
x = BatchNormalization(name='norm_5')(x)
x = LeakyReLU(alpha=0.1)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 6
x = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_6', use_bias=False)(x)
x = BatchNormalization(name='norm_6')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 7
x = Conv2D(128, (1,1), strides=(1,1), padding='same', name='conv_7', use_bias=False)(x)
x = BatchNormalization(name='norm_7')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 8
x = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_8', use_bias=False, input_shape=(416,416,3))(x)
x = BatchNormalization(name='norm_8')(x)
x = LeakyReLU(alpha=0.1)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 9
x = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_9', use_bias=False)(x)
x = BatchNormalization(name='norm_9')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 10
x = Conv2D(256, (1,1), strides=(1,1), padding='same', name='conv_10', use_bias=False)(x)
x = BatchNormalization(name='norm_10')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 11
x = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_11', use_bias=False)(x)
x = BatchNormalization(name='norm_11')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 12
x = Conv2D(256, (1,1), strides=(1,1), padding='same', name='conv_12', use_bias=False)(x)
x = BatchNormalization(name='norm_12')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 13
x = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_13', use_bias=False)(x)
x = BatchNormalization(name='norm_13')(x)
x = LeakyReLU(alpha=0.1)(x)

skip_connection = x

x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 14
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_14', use_bias=False)(x)
x = BatchNormalization(name='norm_14')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 15
x = Conv2D(512, (1,1), strides=(1,1), padding='same', name='conv_15', use_bias=False)(x)
x = BatchNormalization(name='norm_15')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 16
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_16', use_bias=False)(x)
x = BatchNormalization(name='norm_16')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 17
x = Conv2D(512, (1,1), strides=(1,1), padding='same', name='conv_17', use_bias=False)(x)
x = BatchNormalization(name='norm_17')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 18
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_18', use_bias=False)(x)
x = BatchNormalization(name='norm_18')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 19
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_19', use_bias=False)(x)
x = BatchNormalization(name='norm_19')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 20
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_20', use_bias=False)(x)
x = BatchNormalization(name='norm_20')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 21
skip_connection = Conv2D(64, (1,1), strides=(1,1), padding='same', name='conv_21', use_bias=False)(skip_connection)
skip_connection = BatchNormalization(name='norm_21')(skip_connection)
skip_connection = LeakyReLU(alpha=0.1)(skip_connection)
skip_connection = Lambda(space_to_depth_x2)(skip_connection)

x = concatenate([skip_connection, x])

# Layer 22
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_22', use_bias=False)(x)
x = BatchNormalization(name='norm_22')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 23
x = Conv2D(BOX * (4 + 1 + CLASS), (1,1), strides=(1,1), padding='same', name='conv_23')(x)
output = Reshape((GRID_H, GRID_W, BOX, 4 + 1 + CLASS))(x)

# small hack to allow true_boxes to be registered when Keras build the model 
# for more information: https://github.com/fchollet/keras/issues/2790
output = Lambda(lambda args: args[0])([output, true_boxes])

model = Model([input_image, true_boxes], output)

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 416, 416, 3)  0
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 416, 416, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# norm_1 (BatchNormalization)     (None, 416, 416, 32) 128         conv_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 416, 416, 32) 0           norm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 208, 208, 32) 0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, 208, 208, 64) 18432       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# norm_2 (BatchNormalization)     (None, 208, 208, 64) 256         conv_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 208, 208, 64) 0           norm_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 104, 104, 64) 0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv2D)                 (None, 104, 104, 128 73728       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# norm_3 (BatchNormalization)     (None, 104, 104, 128 512         conv_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 104, 104, 128 0           norm_3[0][0]
# __________________________________________________________________________________________________
# conv_4 (Conv2D)                 (None, 104, 104, 64) 8192        leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# norm_4 (BatchNormalization)     (None, 104, 104, 64) 256         conv_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 104, 104, 64) 0           norm_4[0][0]
# __________________________________________________________________________________________________
# conv_5 (Conv2D)                 (None, 104, 104, 128 73728       leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# norm_5 (BatchNormalization)     (None, 104, 104, 128 512         conv_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 104, 104, 128 0           norm_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 52, 52, 128)  0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv_6 (Conv2D)                 (None, 52, 52, 256)  294912      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# norm_6 (BatchNormalization)     (None, 52, 52, 256)  1024        conv_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 52, 52, 256)  0           norm_6[0][0]
# __________________________________________________________________________________________________
# conv_7 (Conv2D)                 (None, 52, 52, 128)  32768       leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# norm_7 (BatchNormalization)     (None, 52, 52, 128)  512         conv_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 52, 52, 128)  0           norm_7[0][0]
# __________________________________________________________________________________________________
# conv_8 (Conv2D)                 (None, 52, 52, 256)  294912      leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# norm_8 (BatchNormalization)     (None, 52, 52, 256)  1024        conv_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 52, 52, 256)  0           norm_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 26, 26, 256)  0           leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv_9 (Conv2D)                 (None, 26, 26, 512)  1179648     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# norm_9 (BatchNormalization)     (None, 26, 26, 512)  2048        conv_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 26, 26, 512)  0           norm_9[0][0]
# __________________________________________________________________________________________________
# conv_10 (Conv2D)                (None, 26, 26, 256)  131072      leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# norm_10 (BatchNormalization)    (None, 26, 26, 256)  1024        conv_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 26, 26, 256)  0           norm_10[0][0]
# __________________________________________________________________________________________________
# conv_11 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# norm_11 (BatchNormalization)    (None, 26, 26, 512)  2048        conv_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 26, 26, 512)  0           norm_11[0][0]
# __________________________________________________________________________________________________
# conv_12 (Conv2D)                (None, 26, 26, 256)  131072      leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# norm_12 (BatchNormalization)    (None, 26, 26, 256)  1024        conv_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 26, 26, 256)  0           norm_12[0][0]
# __________________________________________________________________________________________________
# conv_13 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# norm_13 (BatchNormalization)    (None, 26, 26, 512)  2048        conv_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 26, 26, 512)  0           norm_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 13, 13, 512)  0           leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# conv_14 (Conv2D)                (None, 13, 13, 1024) 4718592     max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# norm_14 (BatchNormalization)    (None, 13, 13, 1024) 4096        conv_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 13, 13, 1024) 0           norm_14[0][0]
# __________________________________________________________________________________________________
# conv_15 (Conv2D)                (None, 13, 13, 512)  524288      leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# norm_15 (BatchNormalization)    (None, 13, 13, 512)  2048        conv_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 13, 13, 512)  0           norm_15[0][0]
# __________________________________________________________________________________________________
# conv_16 (Conv2D)                (None, 13, 13, 1024) 4718592     leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# norm_16 (BatchNormalization)    (None, 13, 13, 1024) 4096        conv_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 13, 13, 1024) 0           norm_16[0][0]
# __________________________________________________________________________________________________
# conv_17 (Conv2D)                (None, 13, 13, 512)  524288      leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# norm_17 (BatchNormalization)    (None, 13, 13, 512)  2048        conv_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 13, 13, 512)  0           norm_17[0][0]
# __________________________________________________________________________________________________
# conv_18 (Conv2D)                (None, 13, 13, 1024) 4718592     leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# norm_18 (BatchNormalization)    (None, 13, 13, 1024) 4096        conv_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 13, 13, 1024) 0           norm_18[0][0]
# __________________________________________________________________________________________________
# conv_19 (Conv2D)                (None, 13, 13, 1024) 9437184     leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# norm_19 (BatchNormalization)    (None, 13, 13, 1024) 4096        conv_19[0][0]
# __________________________________________________________________________________________________
# conv_21 (Conv2D)                (None, 26, 26, 64)   32768       leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 13, 13, 1024) 0           norm_19[0][0]
# __________________________________________________________________________________________________
# norm_21 (BatchNormalization)    (None, 26, 26, 64)   256         conv_21[0][0]
# __________________________________________________________________________________________________
# conv_20 (Conv2D)                (None, 13, 13, 1024) 9437184     leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 26, 26, 64)   0           norm_21[0][0]
# __________________________________________________________________________________________________
# norm_20 (BatchNormalization)    (None, 13, 13, 1024) 4096        conv_20[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 13, 13, 256)  0           leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 13, 13, 1024) 0           norm_20[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 13, 13, 1280) 0           lambda_1[0][0]
#                                                                  leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# conv_22 (Conv2D)                (None, 13, 13, 1024) 11796480    concatenate_1[0][0]
# __________________________________________________________________________________________________
# norm_22 (BatchNormalization)    (None, 13, 13, 1024) 4096        conv_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 13, 13, 1024) 0           norm_22[0][0]
# __________________________________________________________________________________________________
# conv_23 (Conv2D)                (None, 13, 13, 30)   30750       leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 13, 13, 5, 6) 0           conv_23[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1, 1, 1, 50,  0
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 13, 13, 5, 6) 0           reshape_1[0][0]
#                                                                  input_2[0][0]
# ==================================================================================================
# Total params: 50,578,686
# Trainable params: 50,558,014
# Non-trainable params: 20,672
# __________________________________________________________________________________________________

# %%
weight_reader = WeightReader(wt_path)

# %%
weight_reader.all_weights
# Out:
# array([ 0.00000000e+00,  1.40129846e-45,  0.00000000e+00, ...,
#        -3.45636755e-02,  1.21870795e-02,  1.46519216e-02], dtype=float32)

# %%
weight_reader.all_weights.size
# Out:
# 50983565

# %%
weight_reader.reset()
nb_conv = 23

# %%
weight_reader.all_weights
# Out:
# array([ 0.00000000e+00,  1.40129846e-45,  0.00000000e+00, ...,
#        -3.45636755e-02,  1.21870795e-02,  1.46519216e-02], dtype=float32)

# %%
for i in range(1, nb_conv+1):
    conv_layer = model.get_layer('conv_' + str(i))
    
    if i < nb_conv:
        norm_layer = model.get_layer('norm_' + str(i))
        
        size = np.prod(norm_layer.get_weights()[0].shape)

        beta  = weight_reader.read_bytes(size)
        gamma = weight_reader.read_bytes(size)
        mean  = weight_reader.read_bytes(size)
        var   = weight_reader.read_bytes(size)

        weights = norm_layer.set_weights([gamma, beta, mean, var])       
        
    if len(conv_layer.get_weights()) > 1:
        bias   = weight_reader.read_bytes(np.prod(conv_layer.get_weights()[1].shape))
        kernel = weight_reader.read_bytes(np.prod(conv_layer.get_weights()[0].shape))
        kernel = kernel.reshape(list(reversed(conv_layer.get_weights()[0].shape)))
        kernel = kernel.transpose([2,3,1,0])
        conv_layer.set_weights([kernel, bias])
    else:
        kernel = weight_reader.read_bytes(np.prod(conv_layer.get_weights()[0].shape))
        kernel = kernel.reshape(list(reversed(conv_layer.get_weights()[0].shape)))
        kernel = kernel.transpose([2,3,1,0])
        conv_layer.set_weights([kernel])

# %%
layer = model.layers[-4] # the last convolutional layer
weights = layer.get_weights()

new_kernel = np.random.normal(size=weights[0].shape)/(GRID_H*GRID_W)
new_bias   = np.random.normal(size=weights[1].shape)/(GRID_H*GRID_W)

layer.set_weights([new_kernel, new_bias])

# %%
def custom_loss(y_true, y_pred):
    mask_shape = tf.shape(y_true)[:4]
    
    cell_x = tf.to_float(tf.reshape(tf.tile(tf.range(GRID_W), [GRID_H]), (1, GRID_H, GRID_W, 1, 1)))
    cell_y = tf.transpose(cell_x, (0,2,1,3,4))

    cell_grid = tf.tile(tf.concat([cell_x,cell_y], -1), [BATCH_SIZE, 1, 1, 5, 1])
    
    coord_mask = tf.zeros(mask_shape)
    conf_mask  = tf.zeros(mask_shape)
    class_mask = tf.zeros(mask_shape)
    
    seen = tf.Variable(0.)
    total_recall = tf.Variable(0.)
    
    """
    Adjust prediction
    """
    ### adjust x and y      
    pred_box_xy = tf.sigmoid(y_pred[..., :2]) + cell_grid
    
    ### adjust w and h
    pred_box_wh = tf.exp(y_pred[..., 2:4]) * np.reshape(ANCHORS, [1,1,1,BOX,2])
    
    ### adjust confidence
    pred_box_conf = tf.sigmoid(y_pred[..., 4])
    
    ### adjust class probabilities
    pred_box_class = y_pred[..., 5:]
    
    """
    Adjust ground truth
    """
    ### adjust x and y
    true_box_xy = y_true[..., 0:2] # relative position to the containing cell
    
    ### adjust w and h
    true_box_wh = y_true[..., 2:4] # number of cells accross, horizontally and vertically
    
    ### adjust confidence
    true_wh_half = true_box_wh / 2.
    true_mins    = true_box_xy - true_wh_half
    true_maxes   = true_box_xy + true_wh_half
    
    pred_wh_half = pred_box_wh / 2.
    pred_mins    = pred_box_xy - pred_wh_half
    pred_maxes   = pred_box_xy + pred_wh_half       
    
    intersect_mins  = tf.maximum(pred_mins,  true_mins)
    intersect_maxes = tf.minimum(pred_maxes, true_maxes)
    intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
    intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]
    
    true_areas = true_box_wh[..., 0] * true_box_wh[..., 1]
    pred_areas = pred_box_wh[..., 0] * pred_box_wh[..., 1]

    union_areas = pred_areas + true_areas - intersect_areas
    iou_scores  = tf.truediv(intersect_areas, union_areas)
    
    true_box_conf = iou_scores * y_true[..., 4]
    
    ### adjust class probabilities
    true_box_class = tf.argmax(y_true[..., 5:], -1)
    
    """
    Determine the masks
    """
    ### coordinate mask: simply the position of the ground truth boxes (the predictors)
    coord_mask = tf.expand_dims(y_true[..., 4], axis=-1) * COORD_SCALE
    
    ### confidence mask: penelize predictors + penalize boxes with low IOU
    # penalize the confidence of the boxes, which have IOU with some ground truth box < 0.6
    true_xy = true_boxes[..., 0:2]
    true_wh = true_boxes[..., 2:4]
    
    true_wh_half = true_wh / 2.
    true_mins    = true_xy - true_wh_half
    true_maxes   = true_xy + true_wh_half
    
    pred_xy = tf.expand_dims(pred_box_xy, 4)
    pred_wh = tf.expand_dims(pred_box_wh, 4)
    
    pred_wh_half = pred_wh / 2.
    pred_mins    = pred_xy - pred_wh_half
    pred_maxes   = pred_xy + pred_wh_half    
    
    intersect_mins  = tf.maximum(pred_mins,  true_mins)
    intersect_maxes = tf.minimum(pred_maxes, true_maxes)
    intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
    intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]
    
    true_areas = true_wh[..., 0] * true_wh[..., 1]
    pred_areas = pred_wh[..., 0] * pred_wh[..., 1]

    union_areas = pred_areas + true_areas - intersect_areas
    iou_scores  = tf.truediv(intersect_areas, union_areas)

    best_ious = tf.reduce_max(iou_scores, axis=4)
    conf_mask = conf_mask + tf.to_float(best_ious < 0.6) * (1 - y_true[..., 4]) * NO_OBJECT_SCALE
    
    # penalize the confidence of the boxes, which are reponsible for corresponding ground truth box
    conf_mask = conf_mask + y_true[..., 4] * OBJECT_SCALE
    
    ### class mask: simply the position of the ground truth boxes (the predictors)
    class_mask = y_true[..., 4] * tf.gather(CLASS_WEIGHTS, true_box_class) * CLASS_SCALE       
    
    """
    Warm-up training
    """
    no_boxes_mask = tf.to_float(coord_mask < COORD_SCALE/2.)
    seen = tf.assign_add(seen, 1.)
    
    true_box_xy, true_box_wh, coord_mask = tf.cond(tf.less(seen, WARM_UP_BATCHES), 
                          lambda: [true_box_xy + (0.5 + cell_grid) * no_boxes_mask, 
                                   true_box_wh + tf.ones_like(true_box_wh) * np.reshape(ANCHORS, [1,1,1,BOX,2]) * no_boxes_mask, 
                                   tf.ones_like(coord_mask)],
                          lambda: [true_box_xy, 
                                   true_box_wh,
                                   coord_mask])
    
    """
    Finalize the loss
    """
    nb_coord_box = tf.reduce_sum(tf.to_float(coord_mask > 0.0))
    nb_conf_box  = tf.reduce_sum(tf.to_float(conf_mask  > 0.0))
    nb_class_box = tf.reduce_sum(tf.to_float(class_mask > 0.0))
    
    loss_xy    = tf.reduce_sum(tf.square(true_box_xy-pred_box_xy)     * coord_mask) / (nb_coord_box + 1e-6) / 2.
    loss_wh    = tf.reduce_sum(tf.square(true_box_wh-pred_box_wh)     * coord_mask) / (nb_coord_box + 1e-6) / 2.
    loss_conf  = tf.reduce_sum(tf.square(true_box_conf-pred_box_conf) * conf_mask)  / (nb_conf_box  + 1e-6) / 2.
    loss_class = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=true_box_class, logits=pred_box_class)
    loss_class = tf.reduce_sum(loss_class * class_mask) / (nb_class_box + 1e-6)
    
    loss = loss_xy + loss_wh + loss_conf + loss_class
    
    nb_true_box = tf.reduce_sum(y_true[..., 4])
    nb_pred_box = tf.reduce_sum(tf.to_float(true_box_conf > 0.5) * tf.to_float(pred_box_conf > 0.3))

    """
    Debugging code
    """    
    current_recall = nb_pred_box/(nb_true_box + 1e-6)
    total_recall = tf.assign_add(total_recall, current_recall) 

    loss = tf.Print(loss, [tf.zeros((1))], message='Dummy Line \t', summarize=1000)
    loss = tf.Print(loss, [loss_xy], message='Loss XY \t', summarize=1000)
    loss = tf.Print(loss, [loss_wh], message='Loss WH \t', summarize=1000)
    loss = tf.Print(loss, [loss_conf], message='Loss Conf \t', summarize=1000)
    loss = tf.Print(loss, [loss_class], message='Loss Class \t', summarize=1000)
    loss = tf.Print(loss, [loss], message='Total Loss \t', summarize=1000)
    loss = tf.Print(loss, [current_recall], message='Current Recall \t', summarize=1000)
    loss = tf.Print(loss, [total_recall/seen], message='Average Recall \t', summarize=1000)
    
    return loss

# %%
early_stop = EarlyStopping(monitor='val_loss', 
                           min_delta=0.001, 
                           patience=3, 
                           mode='min', 
                           verbose=1)

checkpoint = ModelCheckpoint('weights_blood.h5', 
                             monitor='val_loss', 
                             verbose=1, 
                             save_best_only=True, 
                             mode='min', 
                             period=1)

# %%
tensorboard = TensorBoard()

# %%
optimizer = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

model.compile(loss=custom_loss, optimizer=optimizer)

model.fit_generator(generator        = train_batch, 
                    steps_per_epoch  = len(train_batch), 
                    epochs           = 20, 
                    verbose          = 1,
                    validation_data  = valid_batch,
                    validation_steps = len(valid_batch),
                    callbacks        = [early_stop, checkpoint, tensorboard], 
                    #max_queue_size   = 3)
                    )
# Out:
# Epoch 1/20
# 18/18 [==============================] - 72s 4s/step - loss: 0.3608 - val_loss: 0.1568
#
# Epoch 00001: val_loss improved from inf to 0.15682, saving model to weights_blood.h5
# Epoch 2/20
# 18/18 [==============================] - 57s 3s/step - loss: 0.0855 - val_loss: 0.0991
#
# Epoch 00002: val_loss improved from 0.15682 to 0.09906, saving model to weights_blood.h5
# Epoch 3/20
# 18/18 [==============================] - 57s 3s/step - loss: 0.0587 - val_loss: 0.0729
#
# Epoch 00003: val_loss improved from 0.09906 to 0.07289, saving model to weights_blood.h5
# Epoch 4/20
# 18/18 [==============================] - 57s 3s/step - loss: 0.0471 - val_loss: 0.0609
#
# Epoch 00004: val_loss improved from 0.07289 to 0.06088, saving model to weights_blood.h5
# Epoch 5/20
# 18/18 [==============================] - 57s 3s/step - loss: 0.0392 - val_loss: 0.0474
#
# Epoch 00005: val_loss improved from 0.06088 to 0.04740, saving model to weights_blood.h5
# Epoch 6/20
# 18/18 [==============================] - 57s 3s/step - loss: 0.0321 - val_loss: 0.0357
#
# Epoch 00006: val_loss improved from 0.04740 to 0.03565, saving model to weights_blood.h5
# Epoch 7/20
# 18/18 [==============================] - 57s 3s/step - loss: 0.0252 - val_loss: 0.0231
#
# Epoch 00007: val_loss improved from 0.03565 to 0.02310, saving model to weights_blood.h5
# Epoch 8/20
# 18/18 [==============================] - 57s 3s/step - loss: 0.0183 - val_loss: 0.0154
#
# Epoch 00008: val_loss improved from 0.02310 to 0.01545, saving model to weights_blood.h5
# Epoch 9/20
# 18/18 [==============================] - 57s 3s/step - loss: 0.0127 - val_loss: 0.0120
#
# Epoch 00009: val_loss improved from 0.01545 to 0.01197, saving model to weights_blood.h5
# Epoch 10/20
# 18/18 [==============================] - 57s 3s/step - loss: 0.0092 - val_loss: 0.0095
#
# Epoch 00010: val_loss improved from 0.01197 to 0.00946, saving model to weights_blood.h5
# Epoch 11/20
# 18/18 [==============================] - 57s 3s/step - loss: 0.0069 - val_loss: 0.0082
#
# Epoch 00011: val_loss improved from 0.00946 to 0.00825, saving model to weights_blood.h5
# Epoch 12/20
# 18/18 [==============================] - 57s 3s/step - loss: 0.0051 - val_loss: 0.0064
#
# Epoch 00012: val_loss improved from 0.00825 to 0.00642, saving model to weights_blood.h5
# Epoch 13/20
# 18/18 [==============================] - 58s 3s/step - loss: 0.0039 - val_loss: 0.0054
#
# Epoch 00013: val_loss improved from 0.00642 to 0.00544, saving model to weights_blood.h5
# Epoch 14/20
# 18/18 [==============================] - 57s 3s/step - loss: 0.0031 - val_loss: 0.0048
#
# Epoch 00014: val_loss improved from 0.00544 to 0.00478, saving model to weights_blood.h5
# Epoch 15/20
# 18/18 [==============================] - 57s 3s/step - loss: 0.0027 - val_loss: 0.0039
#
# Epoch 00015: val_loss improved from 0.00478 to 0.00395, saving model to weights_blood.h5
# Epoch 16/20
# 18/18 [==============================] - 57s 3s/step - loss: 0.0022 - val_loss: 0.0033
#
# Epoch 00016: val_loss improved from 0.00395 to 0.00335, saving model to weights_blood.h5
# Epoch 17/20
# 18/18 [==============================] - 57s 3s/step - loss: 0.0018 - val_loss: 0.0029
#
# Epoch 00017: val_loss improved from 0.00335 to 0.00295, saving model to weights_blood.h5
# Epoch 18/20
# 18/18 [==============================] - 57s 3s/step - loss: 0.0016 - val_loss: 0.0024
#
# Epoch 00018: val_loss improved from 0.00295 to 0.00242, saving model to weights_blood.h5
# Epoch 19/20
# 18/18 [==============================] - 56s 3s/step - loss: 0.0013 - val_loss: 0.0020
#
# Epoch 00019: val_loss improved from 0.00242 to 0.00204, saving model to weights_blood.h5
# Epoch 20/20
# 18/18 [==============================] - 56s 3s/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00020: val_loss improved from 0.00204 to 0.00178, saving model to weights_blood.h5
